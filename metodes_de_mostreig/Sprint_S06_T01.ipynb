# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matlab as mat
import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f5c0584c2713> in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 import matlab as mat
#       6 import random
#       7
#
# ModuleNotFoundError: No module named 'matlab'

# %%
from matlab import random
from random import randint
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-9154c6e5e927> in <module>
# ----> 1 from matlab import random
#       2 from random import randint
#
# ModuleNotFoundError: No module named 'matlab'

# %%
olimpic_df1 = pd.read_csv('dictionary.csv')
olimpic_df1
# Out:
#              Country Code  Population  GDP per Capita
# 0        Afghanistan  AFG  32526562.0      594.323081
# 1            Albania  ALB   2889167.0     3945.217582
# 2            Algeria  ALG  39666519.0     4206.031232
# 3    American Samoa*  ASA     55538.0             NaN
# 4            Andorra  AND     70473.0             NaN
# ..               ...  ...         ...             ...
# 196          Vietnam  VIE  91703800.0     2111.138024
# 197  Virgin Islands*  ISV    103574.0             NaN
# 198            Yemen  YEM  26832215.0     1406.291651
# 199           Zambia  ZAM  16211767.0     1304.879014
# 200         Zimbabwe  ZIM  15602751.0      924.143819
#
# [201 rows x 4 columns]

# %%
olimpic_df2 = pd.read_csv('summer.csv')
olimpic_df2
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
olimpic_df3 = pd.read_csv('winter.csv')
olimpic_df3
# Out:
#       Year      City     Sport Discipline               Athlete Country  \
# 0     1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA
# 1     1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA
# 2     1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA
# 3     1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA
# 4     1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI
# ...    ...       ...       ...        ...                   ...     ...
# 5765  2014     Sochi    Skiing  Snowboard          JONES, Jenny     GBR
# 5766  2014     Sochi    Skiing  Snowboard       ANDERSON, Jamie     USA
# 5767  2014     Sochi    Skiing  Snowboard    MALTAIS, Dominique     CAN
# 5768  2014     Sochi    Skiing  Snowboard          SAMKOVA, Eva     CZE
# 5769  2014     Sochi    Skiing  Snowboard      TRESPEUCH, Chloe     FRA
#
#      Gender            Event   Medal
# 0       Men  Military Patrol  Bronze
# ...

# %% [markdown]
# Fem una mostra simple

# %%
simple_olimpic_df2 = olimpic_df2.sample(n = 500)
simple_olimpic_df2
# Out:
#        Year    City          Sport       Discipline                Athlete  \
# 4266   1924   Paris      Athletics        Athletics      WEBBER, George J.
# 24757  2000  Sydney         Rowing           Rowing    ABBAGNALE, Agostino
# 24514  2000  Sydney         Hockey           Hockey       HWANG, Jong-Hyun
# 10402  1960    Rome     Gymnastics      Artistic G.  VATASOIU-LITA, Emilia
# 18806  1988   Seoul       Football         Football    SCHREIER, Christian
# ...     ...     ...            ...              ...                    ...
# 7020   1936  Berlin         Rowing           Rowing        EICHHORN, Willi
# 15881  1980  Moscow       Football         Football          MACELA, Ludek
# 7389   1948  London      Athletics        Athletics           WINTER, John
# 1615   1908  London         Rowing           Rowing     THOMSON, Julius A.
# 6595   1936  Berlin  Canoe / Kayak  Canoe / Kayak F         KOSCHIK, Erich
#
#       Country Gender                                   Event   Medal
# ...

# %% [markdown]
# Ara fem mostra sistèmica generant primer un numero aleatori on començar la mostra
# y després un salt per anar aganfant items de la mostra

# %%
random_number = np.random.randint(1, 100)
random_number
# Out:
# 25

# %%
random_step = np.random.randint(1, 100)
random_step
# Out:
# 27

# %%
systematic_olimpic_df2 = olimpic_df2[random_number : len(olimpic_df2) : random_step]
systematic_olimpic_df2
# Out:
#        Year    City          Sport           Discipline  \
# 25     1896  Athens      Athletics            Athletics
# 52     1896  Athens        Cycling        Cycling Track
# 79     1896  Athens     Gymnastics          Artistic G.
# 106    1896  Athens     Gymnastics          Artistic G.
# 133    1896  Athens         Tennis               Tennis
# ...     ...     ...            ...                  ...
# 31048  2012  London  Weightlifting        Weightlifting
# 31075  2012  London  Weightlifting        Weightlifting
# 31102  2012  London      Wrestling  Wrestling Freestyle
# 31129  2012  London      Wrestling  Wrestling Freestyle
# 31156  2012  London      Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                Event   Medal
# 25                  DANI, Nandor     HUN    Men                 800M  Silver
# 52            KOLETTIS, Georgios     GRE    Men                100KM  Silver
# ...

# %%
olimpic_df2['Country'].value_counts()
# Out:
# USA    4585
# URS    2049
# GBR    1720
# FRA    1396
# GER    1305
#        ...
# BER       1
# TOG       1
# ERI       1
# SUD       1
# BOT       1
# Name: Country, Length: 147, dtype: int64
